# %% [markdown]
# Group: 28 <br>
# 320180939641 Cui, Zeyang <br>
# 320180939721 Fan, Delin <br>
# 320180939951 Li, Ziyuan <br>
# 320180940581 Zhang, Yuhao <br>

# %%
from pylab import *
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. User penetration

# %% [markdown]
# ## a. Replicating

# %%
df = pd.read_csv('data-AiteP.csv')

x = df.year
y1 = df.HKP
y2 = df.SingaporeP
y3 = df.HKR
y4 = df.SingaporeR
y = [y1,y2,y3,y4]

fig, ax = plt.subplots()

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'
plt.ylim(0, 24.9)

#Set the scale interval
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))

# %%
df = pd.read_csv('data-AiteP.csv')

x = df.year
y1 = df.HKP
y2 = df.SingaporeP
y3 = df.HKR
y4 = df.SingaporeR
y = [y1,y2,y3,y4]

fig, ax = plt.subplots()

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'
plt.ylim(0, 24.9)

#Set the scale interval
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 

#Draw the lines
plt.plot(x,y1,'bo--',label='HKP')
plt.plot(x,y2,'go--',label='SingaporeP')
plt.plot(x,y3,'bo-',label='HKR')
plt.plot(x,y4,'go-',label='SingaporeR')

# %%
df = pd.read_csv('data-AiteP.csv')

x = df.year
y1 = df.HKP
y2 = df.SingaporeP
y3 = df.HKR
y4 = df.SingaporeR
y = [y1,y2,y3,y4]

fig, ax = plt.subplots()

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'
plt.ylim(0, 24.9)

#Set the scale interval
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 

#Draw the lines
plt.plot(x,y1,'bo--',label='HKP')
plt.plot(x,y2,'go--',label='SingaporeP')
plt.plot(x,y3,'bo-',label='HKR')
plt.plot(x,y4,'go-',label='SingaporeR')

#Remove the short lines at the grid
tick_params(top='off',bottom='off',left='off',right='off')

plt.grid(axis="y")
plt.title("User penetration")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.show()

# %%
df = pd.read_csv('data-AiteP.csv')

x = df.year
y1 = df.HKP
y2 = df.SingaporeP
y3 = df.HKR
y4 = df.SingaporeR
y = [y1,y2,y3,y4]

fig, ax = plt.subplots()

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'
plt.ylim(0, 24.9)

#Set the scale interval
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 

#Draw the lines
plt.plot(x,y1,'bo--',label='HKP')
plt.plot(x,y2,'go--',label='SingaporeP')
plt.plot(x,y3,'bo-',label='HKR')
plt.plot(x,y4,'go-',label='SingaporeR')

#Remove the short lines at the grid
tick_params(top='off',bottom='off',left='off',right='off')

plt.grid(axis="y")
plt.title("User penetration")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.show()

# %% [markdown]
# ## b. Improving

# %%
fig, ax = plt.subplots()



#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')

plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')

plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')

# %%
fig, ax = plt.subplots()


#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')

plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')

plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')

# %%
fig, ax = plt.subplots()


#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')
plt.yticks([])

plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')
plt.yticks([])

plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')
plt.yticks([])
# Out:
# ([], [])

# %%
fig, ax = plt.subplots()


#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
plt.legend(loc=(0.05,0.05))

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')
plt.yticks([])
plt.legend(loc=(0.05,0.05))

plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))

plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))

# %%
fig, ax = plt.subplots()


#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)


plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)


plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)

# %%
fig, ax = plt.subplots()

#Close the borders
plt.subplots_adjust(left=0, top=1, right=2, bottom=0.08, wspace=0.25, hspace=0)
matplotlib.rc('axes.spines');
matplotlib.rc('axes',facecolor=(1,1,1,0),edgecolor=(1,1,1,0))

#Set the scale interval
y_major_locator=MultipleLocator(8)
ax.yaxis.set_major_locator(y_major_locator)

plt.subplot(1,4,1)
plt.ylim(8,32)
plt.plot(x,y1,'bo--',label='HKP')
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)

plt.subplot(1,4,2)
plt.ylim(8,32)
plt.plot(x,y2,'go--',label='SingaporeP')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)


plt.subplot(1,4,3)
plt.ylim(8,32)
plt.plot(x,y3,'bo-',label='HKR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)


plt.subplot(1,4,4)
plt.ylim(8,32)
plt.plot(x,y4,'go-',label='SingaporeR')
plt.yticks([])
plt.legend(loc=(0.05,0.05))
for i in range(10,31,5):
    plt.hlines(y=i,xmin=0,xmax=3,alpha=0.3,linewidth=1)

# %% [markdown]
# # 2. Plastic dishware waste at landfills in HK

# %% [markdown]
# ## a. Replicating

# %%
df2 = pd.read_csv("data-DWh55.csv")

x_2 = df2.Year
y_2 = df2.Number

ls = zip(x_2.tolist(),y_2.tolist())

# %%
fig, ax = plt.subplots()
plt.bar(x_2,y_2,width=0.7)
# Out:
# <BarContainer object of 4 artists>

# %%
fig, ax = plt.subplots()
plt.bar(x_2,y_2,width=0.7)

left = -0.15
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)

for a,b in ls:
    plt.text(a,b+0.05,'%.0f' % b,ha='center',va='bottom',fontsize=10)
plt.title("Plastic dishware waste at landfills in HK")
# Out:
# Text(0.5, 1.0, 'Plastic dishware waste at landfills in HK')

# %%
fig, ax = plt.subplots()
plt.bar(x_2,y_2,width=0.7)

left = -0.15
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)

for a,b in ls:
    plt.text(a,b+0.05,'%.0f' % b,ha='center',va='bottom',fontsize=10)
plt.title("Plastic dishware waste at landfills in HK")

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(50))

# %%
fig, ax = plt.subplots()
plt.bar(x_2,y_2,width=0.7)

left = -0.15
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)

for a,b in ls:
    plt.text(a,b+0.05,'%.0f' % b,ha='center',va='bottom',fontsize=10)
plt.title("Plastic dishware waste at landfills in HK")

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(50))

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

# %%
fig, ax = plt.subplots()
plt.bar(x_2,y_2,width=0.7)

left = -0.15
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)

for a,b in ls:
    plt.text(a,b+0.05,'%.0f' % b,ha='center',va='bottom',fontsize=10)
plt.title("Plastic dishware waste at landfills in HK")

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(50))

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

plt.grid(axis="y")
plt.rc('axes', axisbelow=True)
tick_params(top='off',bottom='off',left='off',right='off')

# %% [markdown]
# ## b. Improving

# %%
df2 = pd.read_csv("data-DWh55.csv")

x_2 = df2.Year
y_2 = df2.Number

ls = zip(x_2.tolist(),y_2.tolist())

# %%
ax=plt.gca()
plt.plot(x_2,y_2,'o-')

# %%
ax=plt.gca()
plt.plot(x_2,y_2,'o-')

ax.text(2014.95,140,'131')
ax.text(2015.95,163,'154')
ax.text(2016.95,175,'166')
ax.text(2017.95,178,'169',fontsize=12,weight = 'heavy')
ax.text(0.5,1.25,'Plastic dishware waste at landfills in HK',
        weight = 'heavy',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=14)
ax.text(-0.05, 1.15, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
# Out:
# Text(-0.05, 1.15, 'Unit: tonnes per day')

# %%
ax=plt.gca()
plt.plot(x_2,y_2,'o-')

ax.text(2014.95,140,'131')
ax.text(2015.95,163,'154')
ax.text(2016.95,175,'166')
ax.text(2017.95,178,'169',fontsize=12,weight = 'heavy')
ax.text(0.5,1.25,'Plastic dishware waste at landfills in HK',
        weight = 'heavy',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=14)
ax.text(-0.05, 1.15, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

# %%
ax=plt.gca()
plt.plot(x_2,y_2,'o-')

ax.text(2014.95,140,'131')
ax.text(2015.95,163,'154')
ax.text(2016.95,175,'166')
ax.text(2017.95,178,'169',fontsize=12,weight = 'heavy')
ax.text(0.5,1.25,'Plastic dishware waste at landfills in HK',
        weight = 'heavy',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=14)
ax.text(-0.05, 1.15, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(50))
plt.ylim(99,200)
# Out:
# (99.0, 200.0)

# %%
ax=plt.gca()
plt.plot(x_2,y_2,'o-')

ax.text(2014.95,140,'131')
ax.text(2015.95,163,'154')
ax.text(2016.95,175,'166')
ax.text(2017.95,178,'169',fontsize=12,weight = 'heavy')
ax.text(0.5,1.25,'Plastic dishware waste at landfills in HK',
        weight = 'heavy',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=14)
ax.text(-0.05, 1.15, 'Unit: tonnes per day',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(50))
plt.ylim(100,200)
plt.grid(axis="y")

# %% [markdown]
# # 3. HK MSW reduction

# %% [markdown]
# ## a. Replicating

# %%
df3 = pd.read_csv('data_MSW.csv')

x1_3 = df3.Year
y1_3 = df3.MSW
y2_3 = df3.BP
y2_3 = y2_3.dropna()

y2_3.tolist()
# Out:
# [1.0, 0.8]

# %%
fig, ax = plt.subplots()
x_ticks = [i for i in range(2011,2023)]

plt.plot(x1_3,y1_3,'o-')

# %%
fig, ax = plt.subplots()
x_ticks = [i for i in range(2011,2023)]

plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

# %%
fig, ax = plt.subplots()

plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',fontsize=14)

ax.text(2010.5,1.35,'1.27')
ax.text(2016.5,1.3,'1.45')
ax.text(2017.5,1.6,'1.53')
ax.text(2018.5,1.5,'Actual')

ax.text(2016.75,0.9,'1.0')
ax.text(2021.75,0.7,'0.8')
ax.text(2022.5,0.775,'Govt target')
# Out:
# Text(2022.5, 0.775, 'Govt target')

# %%
fig, ax = plt.subplots()

x_ticks = [i for i in range(2011,2023)]
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.xlim(2010,2023)
plt.ylim(0,1.8)


plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',fontsize=14)

ax.text(2010.5,1.35,'1.27')
ax.text(2016.5,1.3,'1.45')
ax.text(2017.5,1.6,'1.53')
ax.text(2018.5,1.5,'Actual')

ax.text(2016.75,0.9,'1.0')
ax.text(2021.75,0.7,'0.8')
ax.text(2022.5,0.775,'Govt target')
# Out:
# Text(2022.5, 0.775, 'Govt target')

# %%
fig, ax = plt.subplots()

x_ticks = [i for i in range(2011,2023)]
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.xlim(2010,2023)
plt.ylim(0,1.8)


plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',fontsize=14)

ax.text(2010.5,1.35,'1.27')
ax.text(2016.5,1.3,'1.45')
ax.text(2017.5,1.6,'1.53')
ax.text(2018.5,1.5,'Actual')

ax.text(2016.75,0.9,'1.0')
ax.text(2021.75,0.7,'0.8')
ax.text(2022.5,0.775,'Govt target')

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

# %%
fig, ax = plt.subplots()

x_ticks = [i for i in range(2011,2023)]
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.xlim(2010,2023)
plt.ylim(0,1.8)


plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',fontsize=14)

ax.text(2010.5,1.35,'1.27')
ax.text(2016.5,1.3,'1.45')
ax.text(2017.5,1.6,'1.53')
ax.text(2018.5,1.5,'Actual')

ax.text(2016.75,0.9,'1.0')
ax.text(2021.75,0.7,'0.8')
ax.text(2022.5,0.775,'Govt target')

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

y_major_locator = MultipleLocator(0.4)
ax.yaxis.set_major_locator(y_major_locator)

# %%
fig, ax = plt.subplots()

x_ticks = [i for i in range(2011,2023)]
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.xlim(2010,2023)
plt.ylim(0,1.8)


plt.plot(x1_3,y1_3,'o-')
x2_3 = [2011,2017,2022]
y2_3 = [1.27,1,0.8]
plt.plot(x2_3,y2_3,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height

ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',fontsize=14)

ax.text(2010.5,1.35,'1.27')
ax.text(2016.5,1.3,'1.45')
ax.text(2017.5,1.6,'1.53')
ax.text(2018.5,1.5,'Actual')

ax.text(2016.75,0.9,'1.0')
ax.text(2021.75,0.7,'0.8')
ax.text(2022.5,0.775,'Govt target')

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

y_major_locator = MultipleLocator(0.4)
ax.yaxis.set_major_locator(y_major_locator)
plt.grid(axis="y")
plt.rc('axes', axisbelow=True)

# %% [markdown]
# ## b. Improving

# %%
y_predict1 = [1.27-(0.27*i/6) for i in range(0,7)]
y_predict2 = [1-(0.2*i/5) for i in range(1,2)]
y_predict1.extend(y_predict2)

year = [i for i in range(2011,2019)]
y1_3 = y1_3.dropna()
y1_3.tolist()
# Out:
# [1.27, 1.3, 1.33, 1.36, 1.4, 1.42, 1.45, 1.53]

# %%
fig, ax = plt.subplots()
plt.plot(year,y1_3,'go-')
plt.plot(year,y_predict1,'bo--')

# %%
fig, ax = plt.subplots()
plt.plot(year,y1_3,'go-')
plt.plot(year,y_predict1,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height
ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',weight = 'heavy',fontsize=14)
#Add the data labels beside the points
ax.text(2010.75,1.35,'1.27')
ax.text(2017.75,1.6,'1.53')
ax.text(2017.75,0.85,'0.96')
# Out:
# Text(2017.75, 0.85, '0.96')

# %%
fig, ax = plt.subplots()
plt.plot(year,y1_3,'go-')
plt.plot(year,y_predict1,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height
ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',weight = 'heavy',fontsize=14)
#Add the data labels beside the points
ax.text(2010.75,1.35,'1.27')
ax.text(2017.75,1.6,'1.53')
ax.text(2017.75,0.85,'0.96')

x_ticks = x1_3.tolist()
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
# Out:
# ([<matplotlib.axis.XTick at 0x2e9b0ee8880>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig, ax = plt.subplots()
plt.plot(year,y1_3,'go-')
plt.plot(year,y_predict1,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height
ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',weight = 'heavy',fontsize=14)
#Add the data labels beside the points
ax.text(2010.75,1.35,'1.27')
ax.text(2017.75,1.6,'1.53')
ax.text(2017.75,0.85,'0.96')

x_ticks = x1_3.tolist()
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.ylim(0.8,1.8)

y_major_locator = MultipleLocator(0.4)
ax.yaxis.set_major_locator(y_major_locator)

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

# %%
fig, ax = plt.subplots()
plt.plot(year,y1_3,'go-')
plt.plot(year,y_predict1,'bo--')

left = -0.07
bottom, height = .25, .75
top = bottom + height
ax.text(left, top, 'Average daily disposal of MSW(kg/person)',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
ax.set_title('HK MSW reduction',weight = 'heavy',fontsize=14)
#Add the data labels beside the points
ax.text(2010.75,1.35,'1.27')
ax.text(2017.75,1.6,'1.53')
ax.text(2017.75,0.85,'0.96')

x_ticks = x1_3.tolist()
tick_params(top='off',bottom='off',left='off',right='off')
plt.xticks(x_ticks)
plt.ylim(0.8,1.8)

y_major_locator = MultipleLocator(0.4)
ax.yaxis.set_major_locator(y_major_locator)

ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
plt.rc('axes', axisbelow=True)

#Draw the area
ax.stackplot(year,y1_3)
ax.stackplot(year,y_predict1,color='white',alpha=0.95)
